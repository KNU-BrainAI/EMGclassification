# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/datasetfornina/ninaprodb1train.pkl
# /kaggle/input/datasetfornina/ninaprodb1test.pkl
# /kaggle/input/datasetforninapro/ninaprodb1train.pkl
# /kaggle/input/datasetforninapro/ninaprodb1test.pkl

# %%
import numpy as np
import os
import random
#from sklearn.model_selection import train_test_split
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers
import math
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
import pickle
# Load the dataset from pickle file
with open('/kaggle/input/datasetfornina/ninaprodb1test.pkl', 'rb') as f:
    test_data = pickle.load(f)
with open('/kaggle/input/datasetfornina/ninaprodb1train.pkl', 'rb') as f:
    train_data = pickle.load(f)

# %%
from sklearn.model_selection import train_test_split

# %%
from tensorflow.keras import layers, Sequential, optimizers, Input, Model

# %% [markdown]
# **WORKED CODE HERE**

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras import optimizers
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.utils import to_categorical
from tqdm import tqdm
import gc
import random
import os

import matplotlib.pyplot as plt
import json

# %%
epochs = 64
learning_rate = 1e-3
batch_size = 16
method = "default"
dataset_type = 1

# %%
import numpy as np
import pandas as pd

import tensorflow as tf

from sklearn.model_selection import train_test_split

from tensorflow.keras.utils import to_categorical


class Nina1Dataset(tf.keras.utils.Sequence):
    def __init__(self, dataframe, batch_size):
        self.dataframe = dataframe
        self.batch_size = batch_size
        
    def __len__(self):
        return int(np.ceil(len(self.dataframe) / self.batch_size))

    def __getitem__(self, idx):
        batch_data = self.dataframe[idx * self.batch_size:(idx + 1) * self.batch_size]

        batch_input_data = []
        batch_labels = []

        for i, target_row in batch_data.iterrows():
            data = target_row['emg'][:500]

            # Zero-Padding
            if len(data) < 500:
                data = np.concatenate((data, np.zeros((500 - len(data), 10))), axis=0)

            # Division data by time-segment
            #input_data = np.transpose(data.reshape((25, 20, 10)), (0, 2, 1))
            input_data = data.reshape((25, 20, 10))
            label = target_row['stimulus']
            #label = to_categorical(label)
            batch_input_data.append(input_data)
            batch_labels.append(label)

        # Check if the batch size is smaller than the desired batch_size
        if len(batch_data) < self.batch_size:
            # Create a dummy batch with all elements set to zero
            dummy_input_data = np.zeros((self.batch_size,) + input_data.shape, dtype=np.float32)
            dummy_labels = np.zeros((self.batch_size,), dtype=np.int32)
            dummy_input_data[:len(batch_input_data)] = np.array(batch_input_data)
            dummy_labels[:len(batch_labels)] = np.array(batch_labels)
            dummy_labels = to_categorical(dummy_labels,num_classes=52)  # Convert labels to one-hot encoding
            
            return dummy_input_data, dummy_labels
        
        batch_labels = to_categorical(batch_labels,num_classes=52)  # Convert labels to one-hot encoding
        
        return np.array(batch_input_data), np.array(batch_labels)





# Parameters
batch_size = 16
train_dir = '/kaggle/input/datasetfornina/ninaprodb1train.pkl'
test_dir = '/kaggle/input/datasetfornina/ninaprodb1test.pkl'

# Set up dataset

train = pd.read_pickle(train_dir)
eval_data = pd.read_pickle(test_dir)

# Load train data
train_data = pd.read_pickle(train_dir)

# Split data into train and validation sets
train_data, val_data = train_test_split(train_data, test_size=0.3, random_state=21)

# Create train, test and validation datasets
train_dataset = Nina1Dataset(train_data, batch_size=batch_size)
val_dataset= Nina1Dataset(val_data, batch_size=batch_size)
test_dataset= Nina1Dataset(eval_data, batch_size=batch_size)


print(train_dataset)
# Out:
# <__main__.Nina1Dataset object at 0x78a5df44f0d0>

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
# Define the CNN-BiLSTM model
from tensorflow.keras.layers import LSTM, Bidirectional, Dropout
from tensorflow.keras.layers import Input, Conv1D, MaxPooling1D, Flatten, Dense, ReLU
from tensorflow.keras.activations import tanh

from tensorflow.keras.models import Model
from tensorflow.keras.layers import Reshape
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.optimizers.schedules import ExponentialDecay
from tensorflow.keras.layers import TimeDistributed

def cnn(x):
    #print(x.shape)
    #x = Reshape((25, 20,10))(x)  
    print(x.shape)
    x = TimeDistributed((Conv1D(64, kernel_size=9, strides=2, padding='same', activation=tanh)))(x)
    print(x.shape)
    #(Batch, 10, 64)

    x = TimeDistributed(MaxPooling1D(pool_size=8, strides=2))(x)
    print(x.shape)
    #(Batch, 2, 64)
    
    x = TimeDistributed((Conv1D(64, kernel_size=5, strides=2, padding='same', activation=tanh)))(x)
    #(Batch, 1, 64)
    x = TimeDistributed(BatchNormalization(epsilon=1e-6, momentum=0.95))(x)
    
    x = TimeDistributed((Conv1D(64, kernel_size=5, strides=2, padding='same', activation=tanh)))(x)
    print(x.shape)
    #(Batch, 1, 64)
    #x = TimeDistributed(Dropout(0.2093))(x)
    x = TimeDistributed(BatchNormalization(epsilon=1e-6, momentum=0.95))(x)
    
    #x = TimeDistributed(ReLU())(Conv1D(64, kernel_size=3, strides=2, padding='same')(x))
    x = TimeDistributed((Conv1D(64, kernel_size=3, strides=2, padding='same', activation=tanh)))(x)
    #print(x.shape)
    #(Batch, 1, 64)
    #x = TimeDistributed(Dropout(0.2093))(x)
    #x = TimeDistributed(BatchNormalization(epsilon=1e-6, momentum=0.95))(x)
    x = TimeDistributed(Flatten())(x)
    print(x.shape)
    # (Batch, 64)

    return x

def Bi_LSTMModel(input_shape,x):
    #model = Sequential()
    # Hidden dimensions
    hidden_dim = 200
    print(x.shape)
    print(11)
    x = Bidirectional(LSTM(hidden_dim, return_sequences=True, dropout=0.2093), input_shape=input_shape)(x)
    #x = Dropout(0.2093)(x)
    print(x.shape)
    print(11)
    x = Bidirectional(LSTM(hidden_dim, return_sequences=True, dropout=0.2093))(x)

    print(x.shape)
    print(11)
    #x = Dropout(0.2093)(x)
    x = Flatten()(x)
    # ( ,10000)

    return x
def EMGHandNet(input_shape, num_classes):
    # Define the input layer
    x = Input(shape=input_shape)
    inputs = x
    #print(x.shape)
    #(batch, 25, 20, 10)
    #temp = [cnn(x[:, t, :, :]) for t in range(x.shape[1])]
    #x = tf.stack(temp, axis=1)
    #print(x.shape)
    x = cnn(x)
   
    #print(x.shape)
    x = Bi_LSTMModel(x.shape[1:],x)
    #print(x.shape)
    #x = Dropout(0.2093)(x)
    x = Dense(512, activation='tanh')(x)
    #print(x.shape)
    x = Dropout(0.2093)(x)

    # Add the output layer
    output_layer = Dense(52, activation='softmax')(x)
    # Create the model
    model = Model(inputs=inputs, outputs=output_layer)

    return model


num_classes = 52  # Adjust based on the number of hand activity classes


# Create an instance of the EMGHandNet model
model = EMGHandNet((25,20,10), 52)


# Compile the model

#dtype = tf.float32

initial_learning_rate = 0.001
decay_steps = 1000
decay_rate = 0.9
batch_size = 16
# Define your model and its optimizer
# Define learning rate schedule
lr_schedule = ExponentialDecay(initial_learning_rate, decay_steps, decay_rate)

    # Compile the model with learning rate schedule
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=lr_schedule, beta_1=0.9, beta_2=0.999),
                loss=tf.keras.losses.CategoricalCrossentropy(from_logits=False),
                metrics=['accuracy'])




history = model.fit(train_dataset,
                    epochs=200,
                    validation_data=val_dataset,
                    batch_size=16
                    )
# Out:
# (None, 25, 20, 10)
# (None, 25, 10, 64)
# (None, 25, 2, 64)
# (None, 25, 1, 64)
# (None, 25, 64)
# (None, 25, 64)
# 11
# (None, 25, 400)
# 11
# (None, 25, 400)
# 11
# Epoch 1/200
# 430/430 [==============================] - 26s 24ms/step - loss: 3.1594 - accuracy: 0.2055 - val_loss: 2.4619 - val_accuracy: 0.3311
# Epoch 2/200
# 430/430 [==============================] - 9s 21ms/step - loss: 2.2997 - accuracy: 0.3631 - val_loss: 2.0859 - val_accuracy: 0.4017
# Epoch 3/200
# 430/430 [==============================] - 9s 22ms/step - loss: 1.7955 - accuracy: 0.4823 - val_loss: 1.7691 - val_accuracy: 0.4885
# Epoch 4/200
# 430/430 [==============================] - 9s 21ms/step - loss: 1.3439 - accuracy: 0.5904 - val_loss: 1.5642 - val_accuracy: 0.5348
# Epoch 5/200
# 430/430 [==============================] - 9s 21ms/step - loss: 0.9370 - accuracy: 0.7028 - val_loss: 1.3369 - val_accuracy: 0.6098
# Epoch 6/200
# 430/430 [==============================] - 10s 24ms/step - loss: 0.6066 - accuracy: 0.8122 - val_loss: 1.2118 - val_accuracy: 0.6520
# Epoch 7/200
# 430/430 [==============================] - 9s 21ms/step - loss: 0.3575 - accuracy: 0.8895 - val_loss: 1.0104 - val_accuracy: 0.7084
# Epoch 8/200
# 430/430 [==============================] - 9s 21ms/step - loss: 0.2118 - accuracy: 0.9406 - val_loss: 1.0263 - val_accuracy: 0.7169
# Epoch 9/200
# 430/430 [==============================] - 9s 21ms/step - loss: 0.1295 - accuracy: 0.9637 - val_loss: 1.0164 - val_accuracy: 0.7247
# Epoch 10/200
# 430/430 [==============================] - 9s 22ms/step - loss: 0.1161 - accuracy: 0.9692 - val_loss: 1.0800 - val_accuracy: 0.7203
# Epoch 11/200
# 430/430 [==============================] - 9s 21ms/step - loss: 0.0843 - accuracy: 0.9789 - val_loss: 1.0122 - val_accuracy: 0.7365
# Epoch 12/200
# 430/430 [==============================] - 9s 21ms/step - loss: 0.0828 - accuracy: 0.9791 - val_loss: 1.0510 - val_accuracy: 0.7280
# Epoch 13/200
# 430/430 [==============================] - 9s 22ms/step - loss: 0.0529 - accuracy: 0.9872 - val_loss: 1.0047 - val_accuracy: 0.7466
# Epoch 14/200
# 430/430 [==============================] - 9s 21ms/step - loss: 0.0439 - accuracy: 0.9910 - val_loss: 1.1217 - val_accuracy: 0.7260
# Epoch 15/200
# 430/430 [==============================] - 9s 21ms/step - loss: 0.0359 - accuracy: 0.9930 - val_loss: 1.2240 - val_accuracy: 0.7017
# Epoch 16/200
# 430/430 [==============================] - 9s 21ms/step - loss: 0.0623 - accuracy: 0.9831 - val_loss: 1.2028 - val_accuracy: 0.7176
# Epoch 17/200
# 430/430 [==============================] - 9s 22ms/step - loss: 0.1109 - accuracy: 0.9656 - val_loss: 1.1627 - val_accuracy: 0.7189
# Epoch 18/200
# 430/430 [==============================] - 9s 21ms/step - loss: 0.0451 - accuracy: 0.9884 - val_loss: 0.9978 - val_accuracy: 0.7561
# Epoch 19/200
# 430/430 [==============================] - 9s 21ms/step - loss: 0.0142 - accuracy: 0.9975 - val_loss: 0.9808 - val_accuracy: 0.7682
# Epoch 20/200
# 430/430 [==============================] - 10s 22ms/step - loss: 0.0081 - accuracy: 0.9991 - val_loss: 0.9368 - val_accuracy: 0.7855
# Epoch 21/200
# 430/430 [==============================] - 9s 21ms/step - loss: 0.0126 - accuracy: 0.9977 - val_loss: 1.0037 - val_accuracy: 0.7733
# Epoch 22/200
# 430/430 [==============================] - 9s 21ms/step - loss: 0.0283 - accuracy: 0.9929 - val_loss: 1.2152 - val_accuracy: 0.7159
# Epoch 23/200
# 430/430 [==============================] - 9s 21ms/step - loss: 0.0353 - accuracy: 0.9919 - val_loss: 1.0125 - val_accuracy: 0.7686
# Epoch 24/200
# 430/430 [==============================] - 9s 22ms/step - loss: 0.0129 - accuracy: 0.9978 - val_loss: 0.9677 - val_accuracy: 0.7797
# Epoch 25/200
# 430/430 [==============================] - 9s 21ms/step - loss: 0.0089 - accuracy: 0.9985 - val_loss: 1.0595 - val_accuracy: 0.7547
# Epoch 26/200
# 430/430 [==============================] - 9s 21ms/step - loss: 0.0050 - accuracy: 0.9993 - val_loss: 0.9941 - val_accuracy: 0.7706
# Epoch 27/200
# 430/430 [==============================] - 9s 22ms/step - loss: 0.0071 - accuracy: 0.9985 - val_loss: 0.9935 - val_accuracy: 0.7801
# Epoch 28/200
# 430/430 [==============================] - 9s 21ms/step - loss: 0.0056 - accuracy: 0.9993 - val_loss: 1.1073 - val_accuracy: 0.7507
# Epoch 29/200
# 430/430 [==============================] - 9s 21ms/step - loss: 0.0151 - accuracy: 0.9962 - val_loss: 1.0083 - val_accuracy: 0.7753
# Epoch 30/200
# 430/430 [==============================] - 10s 22ms/step - loss: 0.0091 - accuracy: 0.9980 - val_loss: 1.0458 - val_accuracy: 0.7713
# Epoch 31/200
# 430/430 [==============================] - 9s 21ms/step - loss: 0.0049 - accuracy: 0.9990 - val_loss: 1.0608 - val_accuracy: 0.7743
# Epoch 32/200
# 430/430 [==============================] - 9s 21ms/step - loss: 0.0046 - accuracy: 0.9991 - val_loss: 1.0297 - val_accuracy: 0.7821
# Epoch 33/200
# 430/430 [==============================] - 9s 22ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.9790 - val_accuracy: 0.7831
# Epoch 34/200
# 430/430 [==============================] - 10s 23ms/step - loss: 9.0126e-04 - accuracy: 1.0000 - val_loss: 0.9528 - val_accuracy: 0.7895
# Epoch 35/200
# 430/430 [==============================] - 9s 21ms/step - loss: 5.5762e-04 - accuracy: 1.0000 - val_loss: 0.9339 - val_accuracy: 0.7902
# Epoch 36/200
# 430/430 [==============================] - 9s 21ms/step - loss: 5.1871e-04 - accuracy: 1.0000 - val_loss: 0.9639 - val_accuracy: 0.7905
# Epoch 37/200
# 430/430 [==============================] - 10s 23ms/step - loss: 0.0059 - accuracy: 0.9983 - val_loss: 1.1227 - val_accuracy: 0.7652
# Epoch 38/200
# 430/430 [==============================] - 9s 21ms/step - loss: 0.0093 - accuracy: 0.9980 - val_loss: 1.0222 - val_accuracy: 0.7828
# Epoch 39/200
# 430/430 [==============================] - 10s 24ms/step - loss: 0.0023 - accuracy: 0.9996 - val_loss: 0.9912 - val_accuracy: 0.7909
# Epoch 40/200
# 430/430 [==============================] - 10s 22ms/step - loss: 9.3495e-04 - accuracy: 1.0000 - val_loss: 0.9822 - val_accuracy: 0.7902
# Epoch 41/200
# 430/430 [==============================] - 9s 21ms/step - loss: 6.2402e-04 - accuracy: 1.0000 - val_loss: 0.9740 - val_accuracy: 0.7963
# Epoch 42/200
# 430/430 [==============================] - 9s 21ms/step - loss: 4.9693e-04 - accuracy: 1.0000 - val_loss: 0.9468 - val_accuracy: 0.8044
# Epoch 43/200
# 430/430 [==============================] - 9s 21ms/step - loss: 4.6733e-04 - accuracy: 1.0000 - val_loss: 0.9805 - val_accuracy: 0.7959
# Epoch 44/200
# 430/430 [==============================] - 10s 23ms/step - loss: 3.3909e-04 - accuracy: 1.0000 - val_loss: 0.9742 - val_accuracy: 0.7959
# Epoch 45/200
# 430/430 [==============================] - 9s 21ms/step - loss: 2.3240e-04 - accuracy: 1.0000 - val_loss: 0.9590 - val_accuracy: 0.7986
# Epoch 46/200
# 430/430 [==============================] - 9s 21ms/step - loss: 2.8491e-04 - accuracy: 1.0000 - val_loss: 0.9666 - val_accuracy: 0.7959
# Epoch 47/200
# 430/430 [==============================] - 10s 23ms/step - loss: 2.4592e-04 - accuracy: 1.0000 - val_loss: 0.9720 - val_accuracy: 0.8003
# Epoch 48/200
# 430/430 [==============================] - 9s 21ms/step - loss: 1.8761e-04 - accuracy: 1.0000 - val_loss: 0.9641 - val_accuracy: 0.7980
# Epoch 49/200
# 430/430 [==============================] - 9s 21ms/step - loss: 1.6764e-04 - accuracy: 1.0000 - val_loss: 0.9577 - val_accuracy: 0.7997
# Epoch 50/200
# 430/430 [==============================] - 10s 23ms/step - loss: 1.4301e-04 - accuracy: 1.0000 - val_loss: 0.9678 - val_accuracy: 0.7986
# Epoch 51/200
# 430/430 [==============================] - 9s 22ms/step - loss: 1.1895e-04 - accuracy: 1.0000 - val_loss: 0.9750 - val_accuracy: 0.8030
# Epoch 52/200
# 430/430 [==============================] - 9s 22ms/step - loss: 1.1231e-04 - accuracy: 1.0000 - val_loss: 0.9705 - val_accuracy: 0.8020
# Epoch 53/200
# 430/430 [==============================] - 9s 21ms/step - loss: 1.1871e-04 - accuracy: 1.0000 - val_loss: 0.9613 - val_accuracy: 0.8014
# Epoch 54/200
# 430/430 [==============================] - 10s 23ms/step - loss: 9.5630e-05 - accuracy: 1.0000 - val_loss: 0.9612 - val_accuracy: 0.8024
# Epoch 55/200
# 430/430 [==============================] - 10s 24ms/step - loss: 8.2405e-05 - accuracy: 1.0000 - val_loss: 0.9792 - val_accuracy: 0.7973
# Epoch 56/200
# 430/430 [==============================] - 9s 21ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 1.0067 - val_accuracy: 0.7905
# Epoch 57/200
# 430/430 [==============================] - 11s 26ms/step - loss: 2.2513e-04 - accuracy: 1.0000 - val_loss: 1.0132 - val_accuracy: 0.7916
# Epoch 58/200
# 430/430 [==============================] - 9s 21ms/step - loss: 1.2221e-04 - accuracy: 1.0000 - val_loss: 1.0062 - val_accuracy: 0.7963
# Epoch 59/200
# 430/430 [==============================] - 9s 21ms/step - loss: 1.0152e-04 - accuracy: 1.0000 - val_loss: 1.0031 - val_accuracy: 0.8000
# Epoch 60/200
# 430/430 [==============================] - 10s 23ms/step - loss: 7.8234e-05 - accuracy: 1.0000 - val_loss: 1.0042 - val_accuracy: 0.7997
# Epoch 61/200
# 430/430 [==============================] - 9s 21ms/step - loss: 7.4224e-05 - accuracy: 1.0000 - val_loss: 0.9944 - val_accuracy: 0.7993
# Epoch 62/200
# 430/430 [==============================] - 9s 21ms/step - loss: 6.0330e-05 - accuracy: 1.0000 - val_loss: 0.9994 - val_accuracy: 0.7970
# Epoch 63/200
# 430/430 [==============================] - 10s 22ms/step - loss: 4.8044e-05 - accuracy: 1.0000 - val_loss: 0.9942 - val_accuracy: 0.7997
# Epoch 64/200
# 430/430 [==============================] - 10s 23ms/step - loss: 4.9765e-05 - accuracy: 1.0000 - val_loss: 0.9918 - val_accuracy: 0.7983
# Epoch 65/200
# 430/430 [==============================] - 10s 24ms/step - loss: 4.3786e-05 - accuracy: 1.0000 - val_loss: 0.9907 - val_accuracy: 0.8010
# Epoch 66/200
# 430/430 [==============================] - 9s 21ms/step - loss: 3.4263e-05 - accuracy: 1.0000 - val_loss: 0.9797 - val_accuracy: 0.8041
# Epoch 67/200
# 430/430 [==============================] - 11s 26ms/step - loss: 3.4582e-05 - accuracy: 1.0000 - val_loss: 0.9923 - val_accuracy: 0.8030
# Epoch 68/200
# 430/430 [==============================] - 9s 22ms/step - loss: 3.3854e-05 - accuracy: 1.0000 - val_loss: 0.9864 - val_accuracy: 0.8010
# Epoch 69/200
# 430/430 [==============================] - 10s 24ms/step - loss: 3.0282e-05 - accuracy: 1.0000 - val_loss: 0.9774 - val_accuracy: 0.8054
# Epoch 70/200
# 430/430 [==============================] - 10s 23ms/step - loss: 3.5288e-05 - accuracy: 1.0000 - val_loss: 1.0021 - val_accuracy: 0.8003
# Epoch 71/200
# 430/430 [==============================] - 9s 22ms/step - loss: 2.5892e-05 - accuracy: 1.0000 - val_loss: 1.0129 - val_accuracy: 0.8047
# Epoch 72/200
# 430/430 [==============================] - 9s 21ms/step - loss: 2.6857e-05 - accuracy: 1.0000 - val_loss: 0.9999 - val_accuracy: 0.8034
# Epoch 73/200
# 430/430 [==============================] - 10s 23ms/step - loss: 2.3697e-05 - accuracy: 1.0000 - val_loss: 1.0058 - val_accuracy: 0.8047
# Epoch 74/200
# 430/430 [==============================] - 10s 24ms/step - loss: 2.3112e-05 - accuracy: 1.0000 - val_loss: 1.0042 - val_accuracy: 0.8041
# Epoch 75/200
# 430/430 [==============================] - 9s 21ms/step - loss: 2.1063e-05 - accuracy: 1.0000 - val_loss: 1.0101 - val_accuracy: 0.8051
# Epoch 76/200
# 430/430 [==============================] - 11s 25ms/step - loss: 1.8559e-05 - accuracy: 1.0000 - val_loss: 1.0071 - val_accuracy: 0.8051
# Epoch 77/200
# 430/430 [==============================] - 9s 22ms/step - loss: 1.7570e-05 - accuracy: 1.0000 - val_loss: 1.0089 - val_accuracy: 0.8061
# Epoch 78/200
# 430/430 [==============================] - 9s 22ms/step - loss: 1.6597e-05 - accuracy: 1.0000 - val_loss: 1.0139 - val_accuracy: 0.8057
# Epoch 79/200
# 430/430 [==============================] - 10s 24ms/step - loss: 1.6001e-05 - accuracy: 1.0000 - val_loss: 1.0286 - val_accuracy: 0.8054
# Epoch 80/200
# 430/430 [==============================] - 9s 22ms/step - loss: 1.5901e-05 - accuracy: 1.0000 - val_loss: 1.0168 - val_accuracy: 0.8071
# Epoch 81/200
# 430/430 [==============================] - 9s 21ms/step - loss: 1.3540e-05 - accuracy: 1.0000 - val_loss: 1.0112 - val_accuracy: 0.8101
# Epoch 82/200
# 430/430 [==============================] - 11s 26ms/step - loss: 1.3348e-05 - accuracy: 1.0000 - val_loss: 1.0347 - val_accuracy: 0.8081
# Epoch 83/200
# 430/430 [==============================] - 9s 21ms/step - loss: 1.0941e-05 - accuracy: 1.0000 - val_loss: 1.0307 - val_accuracy: 0.8054
# Epoch 84/200
# 430/430 [==============================] - 9s 21ms/step - loss: 1.0876e-05 - accuracy: 1.0000 - val_loss: 1.0382 - val_accuracy: 0.8030
# Epoch 85/200
# 430/430 [==============================] - 11s 26ms/step - loss: 1.0450e-05 - accuracy: 1.0000 - val_loss: 1.0202 - val_accuracy: 0.8057
# Epoch 86/200
# 430/430 [==============================] - 9s 22ms/step - loss: 1.1009e-05 - accuracy: 1.0000 - val_loss: 1.0235 - val_accuracy: 0.8068
# Epoch 87/200
# 430/430 [==============================] - 9s 21ms/step - loss: 9.9863e-06 - accuracy: 1.0000 - val_loss: 1.0351 - val_accuracy: 0.8057
# Epoch 88/200
# 430/430 [==============================] - 10s 22ms/step - loss: 9.5398e-06 - accuracy: 1.0000 - val_loss: 1.0364 - val_accuracy: 0.8074
# Epoch 89/200
# 430/430 [==============================] - 10s 22ms/step - loss: 9.9485e-06 - accuracy: 1.0000 - val_loss: 1.0284 - val_accuracy: 0.8068
# Epoch 90/200
# 430/430 [==============================] - 9s 22ms/step - loss: 1.0102e-05 - accuracy: 1.0000 - val_loss: 1.0265 - val_accuracy: 0.8068
# Epoch 91/200
# 430/430 [==============================] - 10s 24ms/step - loss: 8.6814e-06 - accuracy: 1.0000 - val_loss: 1.0352 - val_accuracy: 0.8051
# Epoch 92/200
# 430/430 [==============================] - 11s 25ms/step - loss: 8.5394e-06 - accuracy: 1.0000 - val_loss: 1.0221 - val_accuracy: 0.8118
# Epoch 93/200
# 430/430 [==============================] - 9s 21ms/step - loss: 8.4458e-06 - accuracy: 1.0000 - val_loss: 1.0478 - val_accuracy: 0.8084
# Epoch 94/200
# 430/430 [==============================] - 9s 22ms/step - loss: 7.0272e-06 - accuracy: 1.0000 - val_loss: 1.0270 - val_accuracy: 0.8088
# Epoch 95/200
# 430/430 [==============================] - 12s 27ms/step - loss: 7.3464e-06 - accuracy: 1.0000 - val_loss: 1.0470 - val_accuracy: 0.8051
# Epoch 96/200
# 430/430 [==============================] - 9s 22ms/step - loss: 5.6584e-06 - accuracy: 1.0000 - val_loss: 1.0528 - val_accuracy: 0.8054
# Epoch 97/200
# 430/430 [==============================] - 10s 24ms/step - loss: 6.4639e-06 - accuracy: 1.0000 - val_loss: 1.0390 - val_accuracy: 0.8084
# Epoch 98/200
# 430/430 [==============================] - 10s 23ms/step - loss: 6.8373e-06 - accuracy: 1.0000 - val_loss: 1.0298 - val_accuracy: 0.8098
# Epoch 99/200
# 430/430 [==============================] - 9s 22ms/step - loss: 5.8372e-06 - accuracy: 1.0000 - val_loss: 1.0395 - val_accuracy: 0.8098
# Epoch 100/200
# 430/430 [==============================] - 9s 22ms/step - loss: 5.7136e-06 - accuracy: 1.0000 - val_loss: 1.0415 - val_accuracy: 0.8111
# Epoch 101/200
# 430/430 [==============================] - 11s 26ms/step - loss: 5.8428e-06 - accuracy: 1.0000 - val_loss: 1.0365 - val_accuracy: 0.8088
# Epoch 102/200
# 430/430 [==============================] - 9s 22ms/step - loss: 5.9635e-06 - accuracy: 1.0000 - val_loss: 1.0313 - val_accuracy: 0.8088
# Epoch 103/200
# 430/430 [==============================] - 10s 24ms/step - loss: 5.7480e-06 - accuracy: 1.0000 - val_loss: 1.0332 - val_accuracy: 0.8098
# Epoch 104/200
# 430/430 [==============================] - 11s 25ms/step - loss: 5.2031e-06 - accuracy: 1.0000 - val_loss: 1.0326 - val_accuracy: 0.8088
# Epoch 105/200
# 430/430 [==============================] - 11s 25ms/step - loss: 5.0632e-06 - accuracy: 1.0000 - val_loss: 1.0519 - val_accuracy: 0.8068
# Epoch 106/200
# 430/430 [==============================] - 10s 24ms/step - loss: 4.9175e-06 - accuracy: 1.0000 - val_loss: 1.0306 - val_accuracy: 0.8115
# Epoch 107/200
# 430/430 [==============================] - 10s 22ms/step - loss: 4.9818e-06 - accuracy: 1.0000 - val_loss: 1.0362 - val_accuracy: 0.8081
# Epoch 108/200
# 430/430 [==============================] - 10s 23ms/step - loss: 4.4970e-06 - accuracy: 1.0000 - val_loss: 1.0337 - val_accuracy: 0.8091
# Epoch 109/200
# 430/430 [==============================] - 10s 24ms/step - loss: 4.3690e-06 - accuracy: 1.0000 - val_loss: 1.0577 - val_accuracy: 0.8068
# Epoch 110/200
# 430/430 [==============================] - 10s 22ms/step - loss: 5.4497e-06 - accuracy: 1.0000 - val_loss: 1.0535 - val_accuracy: 0.8078
# Epoch 111/200
# 430/430 [==============================] - 11s 26ms/step - loss: 5.1902e-06 - accuracy: 1.0000 - val_loss: 1.0446 - val_accuracy: 0.8108
# Epoch 112/200
# 430/430 [==============================] - 9s 21ms/step - loss: 4.2681e-06 - accuracy: 1.0000 - val_loss: 1.0476 - val_accuracy: 0.8071
# Epoch 113/200
# 430/430 [==============================] - 11s 25ms/step - loss: 4.1373e-06 - accuracy: 1.0000 - val_loss: 1.0569 - val_accuracy: 0.8074
# Epoch 114/200
# 430/430 [==============================] - 10s 22ms/step - loss: 4.8082e-06 - accuracy: 1.0000 - val_loss: 1.0590 - val_accuracy: 0.8081
# Epoch 115/200
# 430/430 [==============================] - 9s 21ms/step - loss: 4.5605e-06 - accuracy: 1.0000 - val_loss: 1.0404 - val_accuracy: 0.8105
# Epoch 116/200
# 430/430 [==============================] - 10s 24ms/step - loss: 4.5162e-06 - accuracy: 1.0000 - val_loss: 1.0494 - val_accuracy: 0.8098
# Epoch 117/200
# 430/430 [==============================] - 10s 24ms/step - loss: 4.4010e-06 - accuracy: 1.0000 - val_loss: 1.0597 - val_accuracy: 0.8098
# Epoch 118/200
# 430/430 [==============================] - 9s 21ms/step - loss: 5.1812e-06 - accuracy: 1.0000 - val_loss: 1.0425 - val_accuracy: 0.8091
# Epoch 119/200
# 430/430 [==============================] - 9s 21ms/step - loss: 4.4384e-06 - accuracy: 1.0000 - val_loss: 1.0580 - val_accuracy: 0.8108
# Epoch 120/200
# 430/430 [==============================] - 10s 23ms/step - loss: 4.3008e-06 - accuracy: 1.0000 - val_loss: 1.0498 - val_accuracy: 0.8128
# Epoch 121/200
# 430/430 [==============================] - 11s 25ms/step - loss: 4.3024e-06 - accuracy: 1.0000 - val_loss: 1.0437 - val_accuracy: 0.8115
# Epoch 122/200
# 430/430 [==============================] - 9s 21ms/step - loss: 4.0116e-06 - accuracy: 1.0000 - val_loss: 1.0608 - val_accuracy: 0.8098
# Epoch 123/200
# 430/430 [==============================] - 10s 23ms/step - loss: 3.8425e-06 - accuracy: 1.0000 - val_loss: 1.0512 - val_accuracy: 0.8125
# Epoch 124/200
# 430/430 [==============================] - 10s 23ms/step - loss: 3.9359e-06 - accuracy: 1.0000 - val_loss: 1.0531 - val_accuracy: 0.8088
# Epoch 125/200
# 430/430 [==============================] - 9s 22ms/step - loss: 4.0437e-06 - accuracy: 1.0000 - val_loss: 1.0420 - val_accuracy: 0.8098
# Epoch 126/200
# 430/430 [==============================] - 10s 22ms/step - loss: 3.8715e-06 - accuracy: 1.0000 - val_loss: 1.0422 - val_accuracy: 0.8098
# Epoch 127/200
# 430/430 [==============================] - 10s 23ms/step - loss: 3.8165e-06 - accuracy: 1.0000 - val_loss: 1.0552 - val_accuracy: 0.8095
# Epoch 128/200
# 430/430 [==============================] - 9s 22ms/step - loss: 3.7055e-06 - accuracy: 1.0000 - val_loss: 1.0536 - val_accuracy: 0.8091
# Epoch 129/200
# 430/430 [==============================] - 10s 23ms/step - loss: 4.0205e-06 - accuracy: 1.0000 - val_loss: 1.0523 - val_accuracy: 0.8091
# Epoch 130/200
# 430/430 [==============================] - 9s 22ms/step - loss: 4.2389e-06 - accuracy: 1.0000 - val_loss: 1.0437 - val_accuracy: 0.8105
# Epoch 131/200
# 430/430 [==============================] - 10s 23ms/step - loss: 3.6349e-06 - accuracy: 1.0000 - val_loss: 1.0475 - val_accuracy: 0.8118
# Epoch 132/200
# 430/430 [==============================] - 10s 22ms/step - loss: 3.8979e-06 - accuracy: 1.0000 - val_loss: 1.0600 - val_accuracy: 0.8081
# Epoch 133/200
# 430/430 [==============================] - 11s 25ms/step - loss: 3.6053e-06 - accuracy: 1.0000 - val_loss: 1.0415 - val_accuracy: 0.8111
# Epoch 134/200
# 430/430 [==============================] - 10s 23ms/step - loss: 3.8114e-06 - accuracy: 1.0000 - val_loss: 1.0578 - val_accuracy: 0.8118
# Epoch 135/200
# 430/430 [==============================] - 11s 25ms/step - loss: 3.8472e-06 - accuracy: 1.0000 - val_loss: 1.0505 - val_accuracy: 0.8095
# Epoch 136/200
# 430/430 [==============================] - 11s 25ms/step - loss: 3.8048e-06 - accuracy: 1.0000 - val_loss: 1.0564 - val_accuracy: 0.8084
# Epoch 137/200
# 430/430 [==============================] - 10s 23ms/step - loss: 3.8384e-06 - accuracy: 1.0000 - val_loss: 1.0547 - val_accuracy: 0.8091
# Epoch 138/200
# 430/430 [==============================] - 9s 21ms/step - loss: 3.4461e-06 - accuracy: 1.0000 - val_loss: 1.0445 - val_accuracy: 0.8115
# Epoch 139/200
# 430/430 [==============================] - 10s 22ms/step - loss: 3.4356e-06 - accuracy: 1.0000 - val_loss: 1.0518 - val_accuracy: 0.8098
# Epoch 140/200
# 430/430 [==============================] - 9s 21ms/step - loss: 4.1803e-06 - accuracy: 1.0000 - val_loss: 1.0529 - val_accuracy: 0.8105
# Epoch 141/200
# 430/430 [==============================] - 9s 22ms/step - loss: 3.6053e-06 - accuracy: 1.0000 - val_loss: 1.0467 - val_accuracy: 0.8139
# Epoch 142/200
# 430/430 [==============================] - 10s 22ms/step - loss: 3.2119e-06 - accuracy: 1.0000 - val_loss: 1.0557 - val_accuracy: 0.8084
# Epoch 143/200
# 430/430 [==============================] - 11s 25ms/step - loss: 4.5663e-06 - accuracy: 1.0000 - val_loss: 1.0555 - val_accuracy: 0.8105
# Epoch 144/200
# 430/430 [==============================] - 10s 23ms/step - loss: 3.2859e-06 - accuracy: 1.0000 - val_loss: 1.0606 - val_accuracy: 0.8122
# Epoch 145/200
# 430/430 [==============================] - 10s 22ms/step - loss: 4.0622e-06 - accuracy: 1.0000 - val_loss: 1.0567 - val_accuracy: 0.8084
# Epoch 146/200
# 430/430 [==============================] - 9s 21ms/step - loss: 3.1463e-06 - accuracy: 1.0000 - val_loss: 1.0559 - val_accuracy: 0.8101
# Epoch 147/200
# 430/430 [==============================] - 10s 23ms/step - loss: 3.4052e-06 - accuracy: 1.0000 - val_loss: 1.0598 - val_accuracy: 0.8095
# Epoch 148/200
# 430/430 [==============================] - 9s 22ms/step - loss: 6.0876e-06 - accuracy: 1.0000 - val_loss: 1.0503 - val_accuracy: 0.8074
# Epoch 149/200
# 430/430 [==============================] - 11s 26ms/step - loss: 3.5309e-06 - accuracy: 1.0000 - val_loss: 1.0578 - val_accuracy: 0.8095
# Epoch 150/200
# 430/430 [==============================] - 10s 22ms/step - loss: 3.6088e-06 - accuracy: 1.0000 - val_loss: 1.0652 - val_accuracy: 0.8088
# Epoch 151/200
# 430/430 [==============================] - 9s 22ms/step - loss: 3.6565e-06 - accuracy: 1.0000 - val_loss: 1.0730 - val_accuracy: 0.8122
# Epoch 152/200
# 430/430 [==============================] - 11s 25ms/step - loss: 3.5147e-06 - accuracy: 1.0000 - val_loss: 1.0465 - val_accuracy: 0.8108
# Epoch 153/200
# 430/430 [==============================] - 9s 21ms/step - loss: 3.4681e-06 - accuracy: 1.0000 - val_loss: 1.0540 - val_accuracy: 0.8128
# Epoch 154/200
# 430/430 [==============================] - 10s 23ms/step - loss: 3.8126e-06 - accuracy: 1.0000 - val_loss: 1.0443 - val_accuracy: 0.8128
# Epoch 155/200
# 430/430 [==============================] - 10s 23ms/step - loss: 3.3993e-06 - accuracy: 1.0000 - val_loss: 1.0574 - val_accuracy: 0.8101
# Epoch 156/200
# 430/430 [==============================] - 10s 24ms/step - loss: 3.2073e-06 - accuracy: 1.0000 - val_loss: 1.0628 - val_accuracy: 0.8091
# Epoch 157/200
# 430/430 [==============================] - 11s 26ms/step - loss: 3.4434e-06 - accuracy: 1.0000 - val_loss: 1.0557 - val_accuracy: 0.8111
# Epoch 158/200
# 430/430 [==============================] - 11s 25ms/step - loss: 3.4136e-06 - accuracy: 1.0000 - val_loss: 1.0470 - val_accuracy: 0.8142
# Epoch 159/200
# 430/430 [==============================] - 9s 21ms/step - loss: 3.3238e-06 - accuracy: 1.0000 - val_loss: 1.0637 - val_accuracy: 0.8108
# Epoch 160/200
# 430/430 [==============================] - 10s 23ms/step - loss: 3.8148e-06 - accuracy: 1.0000 - val_loss: 1.0616 - val_accuracy: 0.8115
# Epoch 161/200
# 430/430 [==============================] - 10s 22ms/step - loss: 3.1266e-06 - accuracy: 1.0000 - val_loss: 1.0614 - val_accuracy: 0.8111
# Epoch 162/200
# 430/430 [==============================] - 9s 22ms/step - loss: 4.3568e-06 - accuracy: 1.0000 - val_loss: 1.0549 - val_accuracy: 0.8088
# Epoch 163/200
# 430/430 [==============================] - 9s 22ms/step - loss: 4.1685e-06 - accuracy: 1.0000 - val_loss: 1.0514 - val_accuracy: 0.8084
# Epoch 164/200
# 430/430 [==============================] - 10s 23ms/step - loss: 4.0767e-06 - accuracy: 1.0000 - val_loss: 1.0609 - val_accuracy: 0.8111
# Epoch 165/200
# 430/430 [==============================] - 9s 21ms/step - loss: 3.5451e-06 - accuracy: 1.0000 - val_loss: 1.0600 - val_accuracy: 0.8122
# Epoch 166/200
# 430/430 [==============================] - 9s 22ms/step - loss: 3.6235e-06 - accuracy: 1.0000 - val_loss: 1.0517 - val_accuracy: 0.8108
# Epoch 167/200
# 430/430 [==============================] - 11s 26ms/step - loss: 3.1935e-06 - accuracy: 1.0000 - val_loss: 1.0631 - val_accuracy: 0.8091
# Epoch 168/200
# 430/430 [==============================] - 9s 21ms/step - loss: 3.5347e-06 - accuracy: 1.0000 - val_loss: 1.0677 - val_accuracy: 0.8118
# Epoch 169/200
# 430/430 [==============================] - 9s 22ms/step - loss: 3.2226e-06 - accuracy: 1.0000 - val_loss: 1.0591 - val_accuracy: 0.8101
# Epoch 170/200
# 430/430 [==============================] - 10s 23ms/step - loss: 3.3293e-06 - accuracy: 1.0000 - val_loss: 1.0582 - val_accuracy: 0.8095
# Epoch 171/200
# 430/430 [==============================] - 10s 22ms/step - loss: 3.7279e-06 - accuracy: 1.0000 - val_loss: 1.0510 - val_accuracy: 0.8098
# Epoch 172/200
# 430/430 [==============================] - 9s 21ms/step - loss: 3.2758e-06 - accuracy: 1.0000 - val_loss: 1.0621 - val_accuracy: 0.8111
# Epoch 173/200
# 430/430 [==============================] - 9s 21ms/step - loss: 2.9788e-06 - accuracy: 1.0000 - val_loss: 1.0684 - val_accuracy: 0.8071
# Epoch 174/200
# 430/430 [==============================] - 12s 28ms/step - loss: 3.3810e-06 - accuracy: 1.0000 - val_loss: 1.0493 - val_accuracy: 0.8122
# Epoch 175/200
# 430/430 [==============================] - 9s 21ms/step - loss: 3.0714e-06 - accuracy: 1.0000 - val_loss: 1.0527 - val_accuracy: 0.8122
# Epoch 176/200
# 430/430 [==============================] - 10s 24ms/step - loss: 3.1636e-06 - accuracy: 1.0000 - val_loss: 1.0430 - val_accuracy: 0.8149
# Epoch 177/200
# 430/430 [==============================] - 11s 25ms/step - loss: 3.6376e-06 - accuracy: 1.0000 - val_loss: 1.0628 - val_accuracy: 0.8125
# Epoch 178/200
# 430/430 [==============================] - 9s 21ms/step - loss: 3.1526e-06 - accuracy: 1.0000 - val_loss: 1.0735 - val_accuracy: 0.8111
# Epoch 179/200
# 430/430 [==============================] - 10s 22ms/step - loss: 3.3356e-06 - accuracy: 1.0000 - val_loss: 1.0506 - val_accuracy: 0.8088
# Epoch 180/200
# 430/430 [==============================] - 10s 23ms/step - loss: 3.2833e-06 - accuracy: 1.0000 - val_loss: 1.0551 - val_accuracy: 0.8098
# Epoch 181/200
# 430/430 [==============================] - 9s 21ms/step - loss: 2.9945e-06 - accuracy: 1.0000 - val_loss: 1.0626 - val_accuracy: 0.8081
# Epoch 182/200
# 430/430 [==============================] - 9s 22ms/step - loss: 3.4284e-06 - accuracy: 1.0000 - val_loss: 1.0540 - val_accuracy: 0.8135
# Epoch 183/200
# 430/430 [==============================] - 10s 23ms/step - loss: 3.5246e-06 - accuracy: 1.0000 - val_loss: 1.0472 - val_accuracy: 0.8098
# Epoch 184/200
# 430/430 [==============================] - 9s 21ms/step - loss: 3.0291e-06 - accuracy: 1.0000 - val_loss: 1.0615 - val_accuracy: 0.8098
# Epoch 185/200
# 430/430 [==============================] - 9s 21ms/step - loss: 3.3894e-06 - accuracy: 1.0000 - val_loss: 1.0579 - val_accuracy: 0.8139
# Epoch 186/200
# 430/430 [==============================] - 10s 22ms/step - loss: 3.3180e-06 - accuracy: 1.0000 - val_loss: 1.0539 - val_accuracy: 0.8108
# Epoch 187/200
# 430/430 [==============================] - 10s 23ms/step - loss: 3.0668e-06 - accuracy: 1.0000 - val_loss: 1.0654 - val_accuracy: 0.8061
# Epoch 188/200
# 430/430 [==============================] - 9s 21ms/step - loss: 3.3143e-06 - accuracy: 1.0000 - val_loss: 1.0674 - val_accuracy: 0.8078
# Epoch 189/200
# 430/430 [==============================] - 10s 22ms/step - loss: 3.2053e-06 - accuracy: 1.0000 - val_loss: 1.0713 - val_accuracy: 0.8084
# Epoch 190/200
# 430/430 [==============================] - 10s 23ms/step - loss: 3.1326e-06 - accuracy: 1.0000 - val_loss: 1.0440 - val_accuracy: 0.8142
# Epoch 191/200
# 430/430 [==============================] - 9s 21ms/step - loss: 3.2435e-06 - accuracy: 1.0000 - val_loss: 1.0594 - val_accuracy: 0.8098
# Epoch 192/200
# 430/430 [==============================] - 10s 22ms/step - loss: 3.0333e-06 - accuracy: 1.0000 - val_loss: 1.0517 - val_accuracy: 0.8108
# Epoch 193/200
# 430/430 [==============================] - 11s 24ms/step - loss: 3.1512e-06 - accuracy: 1.0000 - val_loss: 1.0554 - val_accuracy: 0.8111
# Epoch 194/200
# 430/430 [==============================] - 11s 24ms/step - loss: 3.2519e-06 - accuracy: 1.0000 - val_loss: 1.0534 - val_accuracy: 0.8101
# Epoch 195/200
# 430/430 [==============================] - 10s 23ms/step - loss: 3.3366e-06 - accuracy: 1.0000 - val_loss: 1.0717 - val_accuracy: 0.8095
# Epoch 196/200
# 430/430 [==============================] - 10s 22ms/step - loss: 3.1479e-06 - accuracy: 1.0000 - val_loss: 1.0620 - val_accuracy: 0.8111
# Epoch 197/200
# 430/430 [==============================] - 10s 24ms/step - loss: 3.3307e-06 - accuracy: 1.0000 - val_loss: 1.0763 - val_accuracy: 0.8091
# Epoch 198/200
# 430/430 [==============================] - 9s 22ms/step - loss: 3.5342e-06 - accuracy: 1.0000 - val_loss: 1.0518 - val_accuracy: 0.8122
# Epoch 199/200
# 430/430 [==============================] - 10s 23ms/step - loss: 3.1932e-06 - accuracy: 1.0000 - val_loss: 1.0501 - val_accuracy: 0.8128
# Epoch 200/200
# 430/430 [==============================] - 10s 23ms/step - loss: 3.5442e-06 - accuracy: 1.0000 - val_loss: 1.0541 - val_accuracy: 0.8098

# %%
true_labels = []  # True labels for the test data
predicted_labels = []  # Predicted labels for the test data

for batch_data, batch_labels in test_dataset:
    batch_predictions = model.predict(batch_data)
    batch_predicted_labels = np.argmax(batch_predictions, axis=1)
    predicted_labels.extend(batch_predicted_labels)
    true_labels.extend(np.argmax(batch_labels, axis=1))

true_labels = np.array(true_labels)
predicted_labels = np.array(predicted_labels)

accuracy = np.mean(true_labels == predicted_labels)

print(accuracy)
# Out:
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 0.8958333333333334
