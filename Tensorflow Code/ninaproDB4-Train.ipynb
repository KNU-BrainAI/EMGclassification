# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/ninapro4/ninaprodb4test.pkl
# /kaggle/input/ninapro4/ninaprodb4train.pkl
# /kaggle/input/datasetforninapro/ninaprodb1train.pkl
# /kaggle/input/datasetforninapro/ninaprodb1test.pkl
# /kaggle/input/datasetfornina/ninaprodb1train.pkl
# /kaggle/input/datasetfornina/ninaprodb1test.pkl

# %%
import numpy as np
import os
import random
#from sklearn.model_selection import train_test_split
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers
import math
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
import pickle
# Load the dataset from pickle file
with open('/kaggle/input/datasetfornina/ninaprodb1test.pkl', 'rb') as f:
    test_data = pickle.load(f)
with open('/kaggle/input/datasetfornina/ninaprodb1train.pkl', 'rb') as f:
    train_data = pickle.load(f)

# %%
from sklearn.model_selection import train_test_split

# %%
from tensorflow.keras import layers, Sequential, optimizers, Input, Model

# %% [markdown]
# **WORKED CODE HERE**

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras import optimizers
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.utils import to_categorical
from tqdm import tqdm
import gc
import random
import os

import matplotlib.pyplot as plt
import json

# %%
epochs = 64
learning_rate = 1e-3
batch_size = 16
method = "default"
dataset_type = 1

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.utils import to_categorical

import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.utils import to_categorical

class Nina1Dataset(tf.keras.utils.Sequence):
    def __init__(self, dataframe, batch_size):
        self.dataframe = dataframe
        self.batch_size = batch_size
        
    def __len__(self):
        return int(np.ceil(len(self.dataframe) / self.batch_size))

    def __getitem__(self, idx):
        batch_data = self.dataframe[idx * self.batch_size:(idx + 1) * self.batch_size]

        batch_input_data = []
        batch_labels = []

        for i, target_row in batch_data.iterrows():
            data = target_row['emg'][:10000]

            # Zero-Padding
            if len(data) < 10000:
                data = np.concatenate((data, np.zeros((10000 - len(data), 12))), axis=0)

            # Division data by time-segment
            #input_data = np.transpose(data.reshape((25, 20, 10)), (0, 2, 1))
            input_data = data.reshape((25, 400, 12))
            label = target_row['stimulus']
            #label = to_categorical(label)
            batch_input_data.append(input_data)
            batch_labels.append(label)

        # Check if the batch size is smaller than the desired batch_size
        if len(batch_data) < self.batch_size:
            # Create a dummy batch with all elements set to zero
            dummy_input_data = np.zeros((self.batch_size,) + input_data.shape, dtype=np.float32)
            dummy_labels = np.zeros((self.batch_size,), dtype=np.int32)
            dummy_input_data[:len(batch_input_data)] = np.array(batch_input_data)
            dummy_labels[:len(batch_labels)] = np.array(batch_labels)
            dummy_labels = to_categorical(dummy_labels,num_classes=52)  # Convert labels to one-hot encoding
            
            return dummy_input_data, dummy_labels
        
        batch_labels = to_categorical(batch_labels,num_classes=52)  # Convert labels to one-hot encoding
        
        return np.array(batch_input_data), np.array(batch_labels)





# Parameters
batch_size = 16
train_dir = '/kaggle/input/ninapro4/ninaprodb4train.pkl'
test_dir = '/kaggle/input/ninapro4/ninaprodb4test.pkl'

# Set up dataset

train = pd.read_pickle(train_dir)
eval_data = pd.read_pickle(test_dir)

# Load train data
train_data = pd.read_pickle(train_dir)

# Split data into train and validation sets
train_data, val_data = train_test_split(train_data, test_size=0.3, random_state=21)

# Create train and validation datasets
train_dataset = Nina1Dataset(train_data, batch_size=batch_size)
val_dataset= Nina1Dataset(val_data, batch_size=batch_size)
test_dataset= Nina1Dataset(eval_data, batch_size=batch_size)


print(train_dataset)
# Out:
# <__main__.Nina1Dataset object at 0x78756f6fb0d0>

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
# Define the CNN-BiLSTM model
from tensorflow.keras.layers import LSTM, Bidirectional, Dropout
from tensorflow.keras.layers import Input, Conv1D, MaxPooling1D, Flatten, Dense, ReLU
from tensorflow.keras.activations import tanh

from tensorflow.keras.models import Model
from tensorflow.keras.layers import Reshape
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.optimizers.schedules import ExponentialDecay
from tensorflow.keras.layers import TimeDistributed

def cnn(x):
    #print(x.shape)
    
    print(x.shape)
    x = TimeDistributed((Conv1D(64, kernel_size=9, strides=2, padding='same', activation=tanh)))(x)
    print(x.shape)
    

    x = TimeDistributed(MaxPooling1D(pool_size=8, strides=2))(x)
    print(x.shape)
   
    
    x = TimeDistributed((Conv1D(64, kernel_size=5, strides=2, padding='same', activation=tanh)))(x)
    
    x = TimeDistributed(BatchNormalization(epsilon=1e-6, momentum=0.95))(x)
    print(x.shape)
    x = TimeDistributed((Conv1D(64, kernel_size=5, strides=2, padding='same', activation=tanh)))(x)
    print(x.shape)
    
    #x = TimeDistributed(Dropout(0.2093))(x)
    x = TimeDistributed(BatchNormalization(epsilon=1e-6, momentum=0.95))(x)
    
    #x = TimeDistributed(ReLU())(Conv1D(64, kernel_size=3, strides=2, padding='same')(x))
    x = TimeDistributed((Conv1D(64, kernel_size=3, strides=2, padding='same', activation=tanh)))(x)
    print(x.shape)
    
    #x = TimeDistributed(Dropout(0.2093))(x)
    #x = TimeDistributed(BatchNormalization(epsilon=1e-6, momentum=0.95))(x)
    x = TimeDistributed(Flatten())(x)
    print(x.shape)
    

    return x

def Bi_LSTMModel(input_shape,x):
    #model = Sequential()
    # Hidden dimensions
    hidden_dim = 200
    print(x.shape)
    x = Bidirectional(LSTM(hidden_dim, return_sequences=True, dropout=0.2093), input_shape=input_shape)(x)
    #x = Dropout(0.2093)(x)
    print(x.shape)
    x = Bidirectional(LSTM(hidden_dim, return_sequences=True, dropout=0.2093))(x)

    print(x.shape)
    #x = Dropout(0.2093)(x)
    x = Flatten()(x)
    # ( ,10000)

    return x
def EMGHandNet(input_shape, num_classes):
    # Define the input layer
    x = Input(shape=input_shape)
    inputs = x
    #print(x.shape)
    
    #temp = [cnn(x[:, t, :, :]) for t in range(x.shape[1])]
    #x = tf.stack(temp, axis=1)
    print(x.shape)
    x = cnn(x)
    #x = Reshape((x.shape[1],x.shape[3]))(x)  # (None,25,1,64) to (None,25,64)
    print(x.shape)
    x = Bi_LSTMModel(x.shape[1:],x)
    print(x.shape)
    #x = Dropout(0.2093)(x)
    x = Dense(512, activation='tanh')(x)
    print(x.shape)
    x = Dropout(0.2093)(x)

    # Add the output layer
    output_layer = Dense(52, activation='softmax')(x)
    # Create the model
    model = Model(inputs=inputs, outputs=output_layer)

    return model


num_classes = 52  # Adjust based on the number of hand activity classes


# Create an instance of the EMGHandNet model
model = EMGHandNet((25,400,12), 52)


# Compile the model

#dtype = tf.float32

initial_learning_rate = 0.001
decay_steps = 1000
decay_rate = 0.9
batch_size = 16
# Define your model and its optimizer
# Define learning rate schedule
lr_schedule = ExponentialDecay(initial_learning_rate, decay_steps, decay_rate)

    # Compile the model with learning rate schedule
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=lr_schedule, beta_1=0.9, beta_2=0.999),
                loss=tf.keras.losses.CategoricalCrossentropy(from_logits=False),
                metrics=['accuracy'])




history = model.fit(train_dataset,
                    epochs=200,
                    validation_data=val_dataset,
                    batch_size=16
                    )
# Out:
# (None, 25, 400, 12)
# (None, 25, 400, 12)
# (None, 25, 200, 64)
# (None, 25, 97, 64)
# (None, 25, 49, 64)
# (None, 25, 25, 64)
# (None, 25, 13, 64)
# (None, 25, 832)
# (None, 25, 832)
# (None, 25, 832)
# (None, 25, 400)
# (None, 25, 400)
# (None, 10000)
# (None, 512)
# Epoch 1/200
# 90/90 [==============================] - 21s 51ms/step - loss: 4.1530 - accuracy: 0.0562 - val_loss: 4.6477 - val_accuracy: 0.0369
# Epoch 2/200
# 90/90 [==============================] - 3s 33ms/step - loss: 2.5971 - accuracy: 0.3160 - val_loss: 6.7403 - val_accuracy: 0.0208
# Epoch 3/200
# 90/90 [==============================] - 3s 34ms/step - loss: 1.5689 - accuracy: 0.5590 - val_loss: 8.3223 - val_accuracy: 0.0272
# Epoch 4/200
# 90/90 [==============================] - 3s 33ms/step - loss: 0.9238 - accuracy: 0.7340 - val_loss: 5.9600 - val_accuracy: 0.0625
# Epoch 5/200
# 90/90 [==============================] - 3s 36ms/step - loss: 0.4761 - accuracy: 0.8674 - val_loss: 6.6544 - val_accuracy: 0.0545
# Epoch 6/200
# 90/90 [==============================] - 3s 33ms/step - loss: 0.2409 - accuracy: 0.9347 - val_loss: 6.6029 - val_accuracy: 0.0513
# Epoch 7/200
# 90/90 [==============================] - 3s 38ms/step - loss: 0.1588 - accuracy: 0.9660 - val_loss: 7.7895 - val_accuracy: 0.0449
# Epoch 8/200
# 90/90 [==============================] - 3s 33ms/step - loss: 0.0696 - accuracy: 0.9840 - val_loss: 5.5097 - val_accuracy: 0.1026
# Epoch 9/200
# 90/90 [==============================] - 3s 33ms/step - loss: 0.0506 - accuracy: 0.9931 - val_loss: 6.0783 - val_accuracy: 0.0913
# Epoch 10/200
# 90/90 [==============================] - 3s 34ms/step - loss: 0.0199 - accuracy: 0.9979 - val_loss: 7.4198 - val_accuracy: 0.0705
# Epoch 11/200
# 90/90 [==============================] - 3s 33ms/step - loss: 0.0192 - accuracy: 0.9951 - val_loss: 5.8488 - val_accuracy: 0.0929
# Epoch 12/200
# 90/90 [==============================] - 3s 33ms/step - loss: 0.0119 - accuracy: 1.0000 - val_loss: 4.5740 - val_accuracy: 0.1538
# Epoch 13/200
# 90/90 [==============================] - 3s 34ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 4.0952 - val_accuracy: 0.2147
# Epoch 14/200
# 90/90 [==============================] - 3s 34ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 4.1864 - val_accuracy: 0.1843
# Epoch 15/200
# 90/90 [==============================] - 3s 33ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss:
# Epoch 148/200
# 90/90 [==============================] - 3s 34ms/step - loss: 3.2286e-06 - accuracy: 1.0000 - val_loss: 4.7560 - val_accuracy: 0.2179
# Epoch 149/200
# 90/90 [==============================] - 3s 33ms/step - loss: 3.2305e-06 - accuracy: 1.0000 - val_loss: 4.7836 - val_accuracy: 0.2163
# Epoch 150/200
# 90/90 [==============================] - 3s 32ms/step - loss: 3.2305e-06 - accuracy: 1.0000 - val_loss: 4.8035 - val_accuracy: 0.2179
# Epoch 151/200
# 90/90 [==============================] - 3s 32ms/step - loss: 3.2822e-06 - accuracy: 1.0000 - val_loss: 4.7887 - val_accuracy: 0.2212
# Epoch 152/200
# 90/90 [==============================] - 3s 35ms/step - loss: 2.9946e-06 - accuracy: 1.0000 - val_loss: 4.7969 - val_accuracy: 0.2228
# Epoch 153/200
# 90/90 [==============================] - 3s 33ms/step - loss: 2.6110e-06 - accuracy: 1.0000 - val_loss: 4.8177 - val_accuracy: 0.2179
# Epoch 154/200
# 90/90 [==============================] - 3s 33ms/step - loss: 2.3921e-06 - accuracy: 1.0000 - val_loss: 4.8236 - val_accuracy: 0.2179
# Epoch 155/200
# 90/90 [==============================] - 3s 37ms/step - loss: 2.7940e-06 - accuracy: 1.0000 - val_loss: 4.8033 - val_accuracy: 0.2196
# Epoch 156/200
# 90/90 [==============================] - 3s 35ms/step - loss: 2.3396e-06 - accuracy: 1.0000 - val_loss: 4.7917 - val_accuracy: 0.2212
# Epoch 157/200
# 90/90 [==============================] - 3s 32ms/step - loss: 2.1501e-06 - accuracy: 1.0000 - val_loss: 4.8196 - val_accuracy: 0.2147
# Epoch 158/200
# 90/90 [==============================] - 3s 34ms/step - loss: 2.1519e-06 - accuracy: 1.0000 - val_loss: 4.8128 - val_accuracy: 0.2067
# Epoch 159/200
# 90/90 [==============================] - 3s 33ms/step - loss: 1.9089e-06 - accuracy: 1.0000 - val_loss: 4.8395 - val_accuracy: 0.2147
# Epoch 160/200
# 90/90 [==============================] - 3s 32ms/step - loss: 1.9794e-06 - accuracy: 1.0000 - val_loss: 4.8518 - val_accuracy: 0.2147
# Epoch 161/200
# 90/90 [==============================] - 3s 34ms/step - loss: 1.9826e-06 - accuracy: 1.0000 - val_loss: 4.8686 - val_accuracy: 0.2131
# Epoch 162/200
# 90/90 [==============================] - 3s 35ms/step - loss: 1.8848e-06 - accuracy: 1.0000 - val_loss: 4.8653 - val_accuracy: 0.2147
# Epoch 163/200
# 90/90 [==============================] - 3s 32ms/step - loss: 1.7695e-06 - accuracy: 1.0000 - val_loss: 4.8601 - val_accuracy: 0.2163
# Epoch 164/200
# 90/90 [==============================] - 3s 34ms/step - loss: 1.7690e-06 - accuracy: 1.0000 - val_loss: 4.8397 - val_accuracy: 0.2147
# Epoch 165/200
# 90/90 [==============================] - 4s 40ms/step - loss: 1.8719e-06 - accuracy: 1.0000 - val_loss: 4.8662 - val_accuracy: 0.2131
# Epoch 166/200
# 90/90 [==============================] - 3s 36ms/step - loss: 8.8951e-07 - accuracy: 1.0000 - val_loss: 4.9625 - val_accuracy: 0.2196
# Epoch 186/200
# 90/90 [==============================] - 3s 36ms/step - loss: 8.9456e-07 - accuracy: 1.0000 - val_loss: 4.9745 - val_accuracy: 0.2244
# Epoch 187/200
# 90/90 [==============================] - 3s 33ms/step - loss: 8.4448e-07 - accuracy: 1.0000 - val_loss: 4.9476 - val_accuracy: 0.2131
# Epoch 188/200
# 90/90 [==============================] - 3s 35ms/step - loss: 7.7858e-07 - accuracy: 1.0000 - val_loss: 4.9690 - val_accuracy: 0.2196
# Epoch 189/200
# 90/90 [==============================] - 3s 34ms/step - loss: 8.3314e-07 - accuracy: 1.0000 - val_loss: 4.9410 - val_accuracy: 0.2147
# Epoch 190/200
# 90/90 [==============================] - 3s 33ms/step - loss: 7.5805e-07 - accuracy: 1.0000 - val_loss: 4.9763 - val_accuracy: 0.2179
# Epoch 191/200
# 90/90 [==============================] - 3s 36ms/step - loss: 7.7395e-07 - accuracy: 1.0000 - val_loss: 4.9852 - val_accuracy: 0.2163
# Epoch 192/200
# 90/90 [==============================] - 3s 33ms/step - loss: 6.7726e-07 - accuracy: 1.0000 - val_loss: 4.9654 - val_accuracy: 0.2083
# Epoch 193/200
# 90/90 [==============================] - 3s 34ms/step - loss: 8.0665e-07 - accuracy: 1.0000 - val_loss: 5.0241 - val_accuracy: 0.2147
# Epoch 194/200
# 90/90 [==============================] - 3s 33ms/step - loss: 6.5350e-07 - accuracy: 1.0000 - val_loss: 5.0252 - val_accuracy: 0.2260
# Epoch 195/200
# 90/90 [==============================] - 3s 37ms/step - loss: 5.9456e-07 - accuracy: 1.0000 - val_loss: 5.0129 - val_accuracy: 0.2244
# Epoch 196/200
# 90/90 [==============================] - 3s 37ms/step - loss: 6.2270e-07 - accuracy: 1.0000 - val_loss: 5.0432 - val_accuracy: 0.2244
# Epoch 197/200
# 90/90 [==============================] - 3s 33ms/step - loss: 6.4100e-07 - accuracy: 1.0000 - val_loss: 4.9872 - val_accuracy: 0.2179
# Epoch 198/200
# 90/90 [==============================] - 3s 33ms/step - loss: 6.6641e-07 - accuracy: 1.0000 - val_loss: 5.0041 - val_accuracy: 0.2163
# Epoch 199/200
# 90/90 [==============================] - 3s 34ms/step - loss: 5.6542e-07 - accuracy: 1.0000 - val_loss: 5.0369 - val_accuracy: 0.2083
# Epoch 200/200
# 90/90 [==============================] - 3s 33ms/step - loss: 5.0920e-07 - accuracy: 1.0000 - val_loss: 5.0440 - val_accuracy: 0.2196

# %%
true_labels = []  # True labels for the test data
predicted_labels = []  # Predicted labels for the test data

for batch_data, batch_labels in test_dataset:
    batch_predictions = model.predict(batch_data)
    batch_predicted_labels = np.argmax(batch_predictions, axis=1)
    predicted_labels.extend(batch_predicted_labels)
    true_labels.extend(np.argmax(batch_labels, axis=1))

true_labels = np.array(true_labels)
predicted_labels = np.array(predicted_labels)

accuracy = np.mean(true_labels == predicted_labels)

print(accuracy)
# Out:
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 0.23846153846153847
